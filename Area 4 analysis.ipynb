# %%
# %matplotlib widget

# %%
# Dependencies

import pandas as pd
import os
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.dates as mdates
from datetime import datetime

# %%
# Read in csv files for each year of data

folder = 'Resources'

df_20 = pd.read_csv(os.path.join(folder,'2020.csv'))
df_19 = pd.read_csv(os.path.join(folder,'2019.csv'))
df_18 = pd.read_csv(os.path.join(folder,'2018.csv'))
df_17 = pd.read_csv(os.path.join(folder,'2017.csv'))
df_16 = pd.read_csv(os.path.join(folder,'2016.csv'))
df_15 = pd.read_csv(os.path.join(folder,'2015.csv'))

# %%
# Merge and select relevent columns from csv

happy_df = df_20[['Country name', 'Regional indicator', 'Ladder score', 'Logged GDP per capita', 'Social support', 'Healthy life expectancy','Freedom to make life choices', 'Generosity', 'Perceptions of corruption']]
happy_df = happy_df.rename(columns={'Ladder score':'Score Y20','Logged GDP per capita':'GDP Y20','Social support':'Social support Y20', 'Healthy life expectancy':'Life expectancy Y20', 'Freedom to make life choices':'Freedom Y20', 'Generosity':'Generosity Y20', 'Perceptions of corruption':'Corruption Y20'})

happy_df = happy_df.merge(df_19[['Country or region', 'Score', 'GDP per capita', 'Social support', 'Healthy life expectancy', 'Freedom to make life choices', 'Generosity', 'Perceptions of corruption']], how='left', left_on='Country name', right_on='Country or region')
happy_df = happy_df.drop(columns='Country or region')
happy_df = happy_df.rename(columns={'Score':'Score Y19', 'GDP per capita':'GDP Y19', 'Social support':'Social support Y19', 'Healthy life expectancy':'Life expectancy Y19', 'Freedom to make life choices':'Freedom Y19', 'Generosity':'Generosity Y19', 'Perceptions of corruption':'Corruption Y19'})

happy_df = happy_df.merge(df_18[['Country or region', 'Score', 'GDP per capita', 'Social support', 'Healthy life expectancy' ,'Freedom to make life choices', 'Generosity', 'Perceptions of corruption']], how='left', left_on='Country name', right_on='Country or region')
happy_df = happy_df.drop(columns='Country or region')
happy_df = happy_df.rename(columns={'Score':'Score Y18', 'GDP per capita':'GDP Y18', 'Social support':'Social support Y18', 'Healthy life expectancy':'Life expectancy Y18', 'Freedom to make life choices':'Freedom Y18', 'Generosity':'Generosity Y18', 'Perceptions of corruption':'Corruption Y18'})

happy_df = happy_df.merge(df_17[['Country', 'Happiness.Score', 'Economy..GDP.per.Capita.', 'Health..Life.Expectancy.', 'Freedom','Generosity', 'Trust..Government.Corruption.']], how='left', left_on='Country name', right_on='Country')
happy_df = happy_df.drop(columns='Country')
happy_df = happy_df.rename(columns={'Happiness.Score':'Score Y17', 'Economy..GDP.per.Capita.':'GDP Y17', 'Health..Life.Expectancy.':'Life Expectancy Y17', 'Freedom':'Freedom Y17', 'Generosity':'Generosity Y17', 'Trust..Government.Corruption.':'Corruption Y17'})

happy_df = happy_df.merge(df_16[['Country', 'Happiness Score', 'Economy (GDP per Capita)', 'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)', 'Generosity']], how='left', left_on='Country name', right_on='Country')
happy_df = happy_df.drop(columns='Country')
happy_df = happy_df.rename(columns={'Happiness Score':'Score Y16', 'Economy (GDP per Capita)':'GDP Y16', 'Health (Life Expectancy)':'Life Expectancy Y16', 'Freedom':'Freedom Y16', 'Trust (Government Corruption)':'Corruption Y16', 'Generosity':'Generosity Y16'})

happy_df = happy_df.merge(df_16[['Country', 'Happiness Score', 'Economy (GDP per Capita)', 'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)', 'Generosity']], how='left', left_on='Country name', right_on='Country')
happy_df = happy_df.drop(columns='Country')
happy_df = happy_df.rename(columns={'Happiness Score':'Score Y15', 'Economy (GDP per Capita)':'GDP Y15', 'Health (Life Expectancy)':'Life Expectancy Y15', 'Freedom':'Freedom Y15', 'Trust (Government Corruption)':'Corruption Y15', 'Generosity':'Generosity Y15'})

happy_df
# Out:
#                  Country name  Regional indicator  Score Y20    GDP Y20  \
# 0                     Finland      Western Europe     7.8087  10.639267
# 1                     Denmark      Western Europe     7.6456  10.774001
# 2                 Switzerland      Western Europe     7.5599  10.979933
# 3                     Iceland      Western Europe     7.5045  10.772559
# 4                      Norway      Western Europe     7.4880  11.087804
# ..                        ...                 ...        ...        ...
# 148  Central African Republic  Sub-Saharan Africa     3.4759   6.625160
# 149                    Rwanda  Sub-Saharan Africa     3.3123   7.600104
# 150                  Zimbabwe  Sub-Saharan Africa     3.2992   7.865712
# 151               South Sudan  Sub-Saharan Africa     2.8166   7.425360
# 152               Afghanistan          South Asia     2.5669   7.462861
#
#      Social support Y20  Life expectancy Y20  Freedom Y20  Generosity Y20  \
# ...

# %%
# Select columns to obtain happiness scores for each year

happiness_time_df = happy_df[['Country name', 'Regional indicator','Score Y15','Score Y16','Score Y17','Score Y18','Score Y19','Score Y20']]
happiness_time_df
# Out:
#                  Country name  Regional indicator  Score Y15  Score Y16  \
# 0                     Finland      Western Europe      7.413      7.413
# 1                     Denmark      Western Europe      7.526      7.526
# 2                 Switzerland      Western Europe      7.509      7.509
# 3                     Iceland      Western Europe      7.501      7.501
# 4                      Norway      Western Europe      7.498      7.498
# ..                        ...                 ...        ...        ...
# 148  Central African Republic  Sub-Saharan Africa        NaN        NaN
# 149                    Rwanda  Sub-Saharan Africa      3.515      3.515
# 150                  Zimbabwe  Sub-Saharan Africa      4.193      4.193
# 151               South Sudan  Sub-Saharan Africa      3.832      3.832
# 152               Afghanistan          South Asia      3.360      3.360
#
#      Score Y17  Score Y18  Score Y19  Score Y20
# 0        7.469      7.632      7.769     7.8087
# ...

# %%
# Top 10 happiest countries in 2020

top10_df = happy_df.sort_values('Score Y20',ascending=False).head(10)
top10_df
# Out:
#   Country name     Regional indicator  Score Y20    GDP Y20  \
# 0      Finland         Western Europe     7.8087  10.639267
# 1      Denmark         Western Europe     7.6456  10.774001
# 2  Switzerland         Western Europe     7.5599  10.979933
# 3      Iceland         Western Europe     7.5045  10.772559
# 4       Norway         Western Europe     7.4880  11.087804
# 5  Netherlands         Western Europe     7.4489  10.812712
# 6       Sweden         Western Europe     7.3535  10.758794
# 7  New Zealand  North America and ANZ     7.2996  10.500943
# 8      Austria         Western Europe     7.2942  10.742824
# 9   Luxembourg         Western Europe     7.2375  11.450681
#
#    Social support Y20  Life expectancy Y20  Freedom Y20  Generosity Y20  \
# 0            0.954330            71.900825     0.949172       -0.059482
# 1            0.955991            72.402504     0.951444        0.066202
# 2            0.942847            74.102448     0.921337        0.105911
# ...

# %%
# Top 10 unhappiest countries in 2020

bottom10_df = happy_df.sort_values('Score Y20',ascending=False).tail(10)
bottom10_df
# Out:
#                  Country name            Regional indicator  Score Y20  \
# 143                     India                    South Asia     3.5733
# 144                    Malawi            Sub-Saharan Africa     3.5380
# 145                     Yemen  Middle East and North Africa     3.5274
# 146                  Botswana            Sub-Saharan Africa     3.4789
# 147                  Tanzania            Sub-Saharan Africa     3.4762
# 148  Central African Republic            Sub-Saharan Africa     3.4759
# 149                    Rwanda            Sub-Saharan Africa     3.3123
# 150                  Zimbabwe            Sub-Saharan Africa     3.2992
# 151               South Sudan            Sub-Saharan Africa     2.8166
# 152               Afghanistan                    South Asia     2.5669
#
#       GDP Y20  Social support Y20  Life expectancy Y20  Freedom Y20  \
# 143  8.849824            0.592201            60.215187     0.881445
# ...

# %%
# Bar chart of top 10 happiest countries in 2020

fig1,ax1 = plt.subplots(figsize=(8,4))
top_country_list = top10_df['Country name']  # Add categories for x axis
x_axis = np.arange(0,len(top_country_list)) # x axis length
top_scores = top10_df['Score Y20'] # y axis values
ax1.set_title("Top 10 happiest countries, 2020")
tick_locations = [value for value in x_axis] # Add tick locations
plt.xticks(tick_locations,top_country_list,rotation=45) # Add x tick labels
plt.xlabel("Country name") # x axis labels
plt.ylabel("Happiness score") # y axis labels
plt.tight_layout() # Fit plot to space
plt.bar(x_axis,top_scores,color='forestgreen') # Generate plot
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# <BarContainer object of 10 artists>

# %%
# Bar chart of top 10 unhappiest countries in 2020

fig1,ax1 = plt.subplots(figsize=(8,4))
bottom_country_list = bottom10_df['Country name']  # Add categories for x axis
x_axis = np.arange(0,len(bottom_country_list)) # x axis length
bottom_scores = bottom10_df['Score Y20'] # y axis values
ax1.set_title("Top 10 unhappiest countries, 2020")
tick_locations = [value for value in x_axis] # Add tick locations
plt.xticks(tick_locations,bottom_country_list,rotation=45) # Add x tick labels
plt.xlabel("Country name") # x axis labels
plt.ylabel("Happiness score") # y axis labels
plt.ylim(top=8) 
plt.tight_layout() # Fit plot to space

plt.bar(x_axis,bottom_scores,color='tab:grey') # Generate plot
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# <BarContainer object of 10 artists>

# %%
# Combine top/bottom 10 countries into a single plot?

# fig, (ax1, ax2)  = plt.subplots(1, 2,sharey=True, figsize=(10,5))

# ax1.bar(top_country_list,top_scores)
# ax2.bar(bottom_country_list,bottom_scores)


# bottom_country_list = bottom10_df['Country name']  # Add categories for x axis
# xaxis2 = np.arange(0,len(bottom_country_list)) # x axis length


# tick_locations = [value for value in x_axis] # Add tick locations
# plt.xticks(tick_locations,top_country_list,rotation=45) # Add x tick labels
# plt.xticks(tick_locations,bottom_country_list,rotation=45) # Add x tick labels
# plt.tight_layout() # Fit plot to space
# plt.show()

# %%
# Box plot showing distribution of happiness scores, 2020
# df = happiness_time_df[['Score Y15','Score Y16','Score Y17','Score Y18','Score Y19','Score Y20']]
# df['Score Y20']
  
fig1, ax1 = plt.subplots()
ax1.set_title("Distribution of happiness scores")
ax1.set_ylabel("Happiness score")
# ax1.set_xlabel("Year")
green_diamond = dict(markerfacecolor='g', marker='D') # Change outlier marker
ax1.boxplot(df['Score Y20'], flierprops=green_diamond) # Plot with new outlier marker
plt.show()
plt.xticks([1],["2020"])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# ([<matplotlib.axis.XTick at 0x7fd5ac4e31d0>],
#  <a list of 1 Text xticklabel objects>)

# %% [markdown]
# ## Happiness and time
#
# * Are we getting happier on a global scale? Looking at global happiness from 2015 to 2020.

# %%
# Plot happiness over time for top 10 countries

# %%
# Plot happiness over time for bottom 10 countries

# %%
# Derive a global happiness score (mean) and global happiness score (median), based on averages of total.
# Which makes more sense, median or mean?
global_happiness_median = happiness_time_df.iloc[:,2:8].median().round(2)
global_happiness_median
# Out:
# Score Y15    5.30
# Score Y16    5.30
# Score Y17    5.29
# Score Y18    5.36
# Score Y19    5.37
# Score Y20    5.51
# dtype: float64

# %%
global_happiness_mean = happiness_time_df.iloc[:,2:8].mean().round(2)
global_happiness_mean
# Out:
# Score Y15    5.38
# Score Y16    5.38
# Score Y17    5.38
# Score Y18    5.39
# Score Y19    5.41
# Score Y20    5.47
# dtype: float64

# %%
global_happiness_df = pd.DataFrame({'Median global happiness':global_happiness_median})                                    
global_happiness_df
# Out:
#            Median global happiness
# Score Y15                     5.30
# Score Y16                     5.30
# Score Y17                     5.29
# Score Y18                     5.36
# Score Y19                     5.37
# Score Y20                     5.51

# %%
# Plot median global happiness from 2015 to 2020
fig1, ax1 = plt.subplots()
ax1.set_title("Global happiness")
ax1.set_ylabel("Median global happiness score")
ax1.set_xlabel("Year")
positions = (0,1,2,3,4,5)
labels = ("2015", "2016", "2017","2018","2019","2020")
plt.xticks(positions,labels)
plt.ylim(bottom=5,top=6) 
plt.plot(global_happiness_df, marker='o',color='tab:purple')
plt.show()

# How to annotate?
# plt.annotate ('Some event', xy=(2017, 5.30), xytext=(2017, 5.35),arrowprops=dict(facecolor='black', shrink=0.05))

# Add other factors to the plot also
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.close('all')
